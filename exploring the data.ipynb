# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt
import statistics
plt.style.use('ggplot')
import seaborn as sns
import matplotlib.patches as mpatches

# %%
df = pd.read_csv('prod_with_chem.csv')
df.mean()
# Out:
# Unnamed: 0     0.000000
# num_chem       1.381409
# price         23.512428
# dtype: float64

# %%
num = df['num_chem'].tolist()
price = df['price'].tolist()

# %%
fig, ax = plt.subplots( figsize=(13, 4))

ax = sns.scatterplot(x="price", y="num_chem", data=df, hue = 'num_chem',palette="Blues_r")

plt.title("Number of Toxic Chemical per Price", color='#333333', fontsize = 15, weight='bold') 
plt.ylabel("Toxic Chemicals", fontsize=15, labelpad=10)
plt.xlabel("Price",fontsize=15, labelpad=10)
plt.tight_layout() 

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('grey')
ax.spines['bottom'].set_color('grey')

ax.set_axisbelow(True)
ax.yaxis.grid(False)
ax.xaxis.grid(False)

fig.tight_layout()
ax.tick_params(bottom=False, left=False)
ax.set_facecolor('white')
ax.get_legend().remove()
ax.text(24,12.5,'Mean Price', fontsize =13 , color='grey')
ax.axvline(23.5, .03, .9, color = 'navy', alpha = .5)

# %%
list_1 = ['Bath & Body Accessories','Cleansers','Body Moisturizers', 'Moisturizers', 'Skin', 'Skin Care', 'Suncare', 'Treatment & Serums']
df_face = df[df['category'].isin(list_1)]

# %%
df_face = df_face.drop(['name', 'mfg', 'chem', 'category'], axis=1)

# %%
list_2 = ['Lips','Face','Eyes']
df_makeup = df[df['category'].isin(list_2)]

# %%
df_makeup=df_makeup.drop(['name', 'mfg', 'chem', 'category'], axis=1)

# %%
face_num = df_face['num_chem'].tolist()
face_price = df_face['price'].tolist()

# %%
mak_num = df_makeup['num_chem'].tolist()
mak_price = df_makeup['price'].tolist()

# %%
fig, ax = plt.subplots(figsize= (10,8))


ax.hist(face_num,alpha = .5, color = 'green')
ax.hist(mak_num, alpha = .5, color = 'purple')

plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.xlabel("Count of Toxic Chemicals", fontsize=20, labelpad=20)  
plt.ylabel("Number of Products", fontsize=20, labelpad=20) 
ax.set_title('Makeup vs Skin Care', pad=20, color='#333333', fontsize = 20,
             weight='bold')
ax.get_yaxis().set_visible(True)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('grey')

ax.set_axisbelow(True)

ax.yaxis.grid(True, color='lightgrey')
ax.xaxis.grid(False)

mak = mpatches.Patch(color='green', label='Makeup')
skin = mpatches.Patch(color='purple', label='Skin Care')
plt.legend(handles=[mak, skin])




fig.tight_layout()
ax.tick_params(bottom=False, left=False)
ax.set_facecolor('white')
# %%capture
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
fig, ax = plt.subplots(1, figsize=(16, 3))

ax.scatter(face_num, np.repeat(0, len(face_num)), s=45)
ax.scatter(mak_num, np.repeat(1, len(mak_num)), s =45)

ax.set_yticks([0, 1])
ax.set_yticklabels(["lux", "basic"])
# Out:
# [Text(0, 0, 'lux'), Text(0, 0, 'basic')]

# %%
fig, ax = plt.subplots(1, figsize=(8, 5))
ax.boxplot([mak_num, face_num])
ax.set_xticks([1,2])
ax.set_xticklabels(["mak", "face"])
# Out:
# [Text(0, 0, 'mak'), Text(0, 0, 'face')]
